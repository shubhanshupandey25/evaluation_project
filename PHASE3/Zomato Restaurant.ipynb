# %% [markdown]
# # Zomato Restaurant

# %%
#importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df = pd.read_csv('zomato.csv')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#importing country data
con=pd.read_excel(r'C:\Users\Administrator\Downloads\Book1.xlsx')

# %%
con
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
#merging the both the dataset
df=pd.merge(df,con,on='Country Code')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
#shape of the dataset
print('DataSet contains :')
print('Number of columns :',df.shape[1])
print('Number of Rows :',df.shape[0])
# Out:
# DataSet contains :
# Number of columns : 22
# Number of Rows : 9551

# %%
#checking for columns
df.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes',
#  'Country']

# %%
#checking for datatype
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
#checking for info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# There are 3 columns are of float datatype,5 columns are of int64 and 14 columns are of 14 datatypes.

# %%
#checking for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#checking for unique values
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
#checking for value counts of each column
for i in df.columns:
    print(i,':\n')
    print(df[i].value_counts())
    print('_'*125)
# Out:
# Restaurant ID :
#
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
# _____________________________________________________________________________________________________________________________
# Restaurant Name :
#
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# _____________________________________________________________________________________________________________________________
# Country Code :
#
# 1      8652
# 216     434
# 215      80
# ...

# %%
#checking for null values
print(df.isnull().sum())

sns.heatmap(df.isnull())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64
# <Axes: >

# %% [markdown]
# There is presence of null values

# %%
#droping unwanted columns
df=df.drop(columns=['Restaurant ID','Country Code','Address','Locality Verbose','Switch to order menu','Switch to order menu','Rating color'])

# %%
df.shape
# Out:
# (9551, 16)

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#          Longitude     Latitude  Average Cost for two  Price range  \
# count  9551.000000  9551.000000           9551.000000  9551.000000
# mean     64.126574    25.854381           1199.210763     1.804837
# std      41.467058    11.007935          16121.183073     0.905609
# min    -157.948486   -41.330428              0.000000     1.000000
# 25%      77.081343    28.478713            250.000000     1.000000
# 50%      77.191964    28.570469            400.000000     2.000000
# 75%      77.282006    28.642758            700.000000     2.000000
# max     174.832089    55.976980         800000.000000     4.000000
#
#        Aggregate rating         Votes
# count       9551.000000   9551.000000
# mean           2.666370    156.909748
# std            1.516378    430.169145
# min            0.000000      0.000000
# 25%            2.500000      5.000000
# 50%            3.200000     31.000000
# 75%            3.700000    131.000000
# max            4.900000  10934.000000

# %% [markdown]
# * All counts are same there are no null values
# * There is a differnece between mean value and median(50%)value which indicates that datasets are skewed.
# * There is a large gap between maximum value and 75% percentile which means there maybe the presence of outliers.
# * Minimum vote is 15.90 and maximum is 10934
# * Minimum aggregate rating is 0 and maximum is 4.9.

# %%
#separating numerical and categorical data
cat_col=[]
for col in df.columns:
    if df[col].dtypes=='object':
        cat_col.append(col)
print('Categorical column :',cat_col)
print('\n')
num_col=[]
for col in df.columns:
    if df[col].dtypes!='object':
        num_col.append(col)
print('Numerical Column :',num_col)
# Out:
# Categorical column : ['Restaurant Name', 'City', 'Locality', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Rating text', 'Country']
#
#
# Numerical Column : ['Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %% [markdown]
# # Exploratory Data Analysis  (EDA) and Visualization

# %%
sns.countplot(x='Price range',palette='rainbow',data=df)
print(df['Price range'].value_counts())
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# Counts are more for price range 1 followed by 2,3,and 4

# %%
column=['Currency','Has Table booking', 'Has Online delivery', 'Is delivering now', 'Rating text', 'Country']

plt.figure(figsize=(30,25),facecolor='yellow')
pltnum=1
for i in column:
    if pltnum<=5:
        ax=plt.subplot(3,2,pltnum)
        sns.countplot(x=i,data=df,palette='plasma')
        plt.xticks(rotation=90,fontweight='bold',fontsize=20)
        plt.yticks(fontweight='bold')
        plt.xlabel(i,fontweight='bold',fontsize=30)
        plt.ylabel('count',fontweight='bold',fontsize=20)
        pltnum+=1

plt.tight_layout()
plt.show()

# %% [markdown]
# Rating text is more for 'Average'

# %%
plt.figure(figsize=(15,8))
ab=sns.countplot(x='Aggregate rating',data=df,palette='rainbow',edgecolor='black')
plt.xlabel('Aggregate rating',fontweight='bold',fontsize=15)
plt.ylabel('Count',fontweight='bold',fontsize=15)

for i in ab.containers:
    ab.bar_label(i,fontsize=10)
plt.show()

# %% [markdown]
#      Most of the customers are rated for 0 and least customer is rated for 1.8                                                      And 61 customers are rated for highst rating 4.9.

# %%
#checking for country who is got more 0 ratings
rating=df[df['Aggregate rating']==0].groupby('Country').size().sort_values(ascending=False).reset_index()
rating=rating.rename(columns={0:'count'})
rating
# Out:
#           Country  count
# 0           India   2139
# 1          Brazil      5
# 2   United States      3
# 3  United Kingdom      1

# %% [markdown]
# india got most zero ratings

# %%
filter = df[df['Country']=='India']
plt.figure(figsize=(15,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='plasma')
plt.xlabel("Rating text",fontsize=15,fontweight='bold')
plt.ylabel("Average Cost for two",fontsize=15,fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in India',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=20,rotation=60)
plt.show()

# %% [markdown]
# in india :
#
# * Price range 4 received the most "Good" ratings.
# * Price range 3 received the most "Excellent" ratings.
# * Price range 2 received the most "Very Good" ratings.
# * Price range 1 received the most "Poor" ratings.

# %%
sns.barplot(y=df['Average Cost for two'],x=df['Has Table booking'],hue=df['Price range'])
# Out:
# <Axes: xlabel='Has Table booking', ylabel='Average Cost for two'>

# %% [markdown]
# When table booking is available, the "Average Cost for two" and "Price range" tend to be higher.

# %% [markdown]
# India,United States got more heighst rating which is 4.9

# %%
filter = df[df['Country']=='United States']
plt.figure(figsize=(15,8))
cat=sns.barplot(data=filter, x='Rating text',y='Average Cost for two',hue='Price range',palette='plasma')
plt.xlabel("Rating text",fontsize=15,fontweight='bold')
plt.ylabel("Average Cost for two",fontsize=15,fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Rating text Vs Average Cost for two Vs Price range in India',fontsize=15)

for i in cat.containers:
    cat.bar_label(i,fontsize=10,padding=20,rotation=60)
plt.show()

# %% [markdown]
# in United States :
#
# * Price range 4 received the most "Excellent" ratings.
# * Price range 3 received the most "Average" and "Very Good" ratings.
# * Price range 2 received a mix of almost all ratings.
# * Price range 1 received the most "Poor" and "Excellent" ratings.

# %%
cuisine_price_counts = df.groupby(['Cuisines', 'Price range']).size().reset_index(name='Count')

top_cuisine_price_counts = cuisine_price_counts.sort_values(by='Count', ascending=False).head(10)

top_cuisine_price_counts
# Out:
#                    Cuisines  Price range  Count
# 1619           North Indian            1    691
# 1029              Fast Food            1    309
# 1652  North Indian, Chinese            2    261
# 611                 Chinese            1    240
# 1905  North Indian, Mughlai            2    210
# 1620           North Indian            2    188
# 1651  North Indian, Chinese            1    175
# 218                  Bakery            1    172
# 2213            Street Food            1    147
# 408                    Cafe            2    139

# %%
plt.figure(figsize=(7, 6))
colors=sns.set_palette('rainbow')
plt.barh(top_cuisine_price_counts['Cuisines'],top_cuisine_price_counts['Price range'], color=colors)
plt.ylabel('Name of Cuisines')
plt.xlabel('Price range')
plt.title('Top 10 cuisines vs price range')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# North indian,North indian chinese,cafe cuisines are popular cuisines which got the  price range of 2

# %%
bottom_cuisine_price_counts = cuisine_price_counts.sort_values(by='Count', ascending=True).head(10)

bottom_cuisine_price_counts
# Out:
#                                    Cuisines  Price range  Count
# 0                                   Afghani            1      1
# 1410        Juices, Beverages, Healthy Food            2      1
# 1409           Juices, Beverages, Fast Food            1      1
# 1408                      Juices, Beverages            1      1
# 1406  Japanese, Tibetan, Vietnamese, Korean            2      1
# 1405                  Japanese, Thai, Sushi            4      1
# 1403                Japanese, Thai, Chinese            3      1
# 1402                  Japanese, Sushi, Thai            3      1
# 1400              Japanese, Sushi, Teriyaki            2      1
# 1399                 Japanese, Sushi, Ramen            3      1

# %%
plt.figure(figsize=(7, 6))
colors=sns.set_palette('rainbow')
plt.barh(bottom_cuisine_price_counts['Cuisines'],bottom_cuisine_price_counts['Price range'], color=colors)
plt.ylabel('Name of Cuisines')
plt.xlabel('Price range')
plt.title('bottom 10 cuisines vs price range')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# * Afghani,Juices, Beverages, fast Food, cuisines are got least price tags.
# * Japanese,thai,sushi have the price range of 4

# %%
cuisine_cost_counts = df.groupby(['Cuisines', 'Average Cost for two']).size().reset_index(name='Count')

top_cuisine_cost_counts = cuisine_cost_counts.sort_values(by='Count',ascending=False).head(10)

top_cuisine_cost_counts
# Out:
#                    Cuisines  Average Cost for two  Count
# 2401           North Indian                   200    173
# 2404           North Indian                   300    116
# 2406           North Indian                   400    104
# 587                    Cafe                   450     87
# 2408           North Indian                   500     86
# 2480  North Indian, Chinese                   500     81
# 2400           North Indian                   150     80
# 3180       Pizza, Fast Food                   700     79
# 2482  North Indian, Chinese                   600     69
# 870                 Chinese                   300     69

# %%
plt.figure(figsize=(7, 6))
colors=sns.set_palette('rainbow')
plt.barh(top_cuisine_cost_counts['Cuisines'],top_cuisine_cost_counts['Average Cost for two'], color=colors)
plt.ylabel('Name of Cuisines')
plt.xlabel('Average Cost for two')
plt.title('Top 10 cuisines vs Average Cost for two')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# * Most popular cuisine is North indian,North indian chinese which have the average cost for two is 500.
# * Pizza,fast food have the average cost for two is 700.

# %%
bottom_cuisine_cost_counts = cuisine_cost_counts.sort_values(by='Count',ascending=True).head(10)

bottom_cuisine_cost_counts
# Out:
#                                Cuisines  Average Cost for two  Count
# 0                               Afghani                   300      1
# 2133                  Lebanese, Arabian                   120      1
# 2135  Lebanese, Arabian, Middle Eastern                    70      1
# 2136        Lebanese, Arabian, Moroccan                   750      1
# 2138                  Lebanese, Chinese                   500      1
# 2139       Lebanese, Chinese, Fast Food                   300      1
# 2140                  Lebanese, Italian                   650      1
# 2141   Lebanese, Mediterranean, Arabian                   850      1
# 2143             Lebanese, North Indian                  1500      1
# 2144  Lebanese, North Indian, Fast Food                   250      1

# %%
plt.figure(figsize=(7, 6))
colors=sns.set_palette('rainbow')
plt.barh(bottom_cuisine_cost_counts['Cuisines'],bottom_cuisine_cost_counts['Average Cost for two'], color=colors)
plt.ylabel('Name of Cuisines')
plt.xlabel('Average Cost for two')
plt.title('bottom 10 cuisines vs Average Cost for two')
plt.gca().invert_yaxis()
plt.show()

# %%
locality_cost_counts = df.groupby(['Locality', 'Average Cost for two']).size().reset_index(name='Count')

top_locality_cost_counts = locality_cost_counts.sort_values(by='Count', ascending=False).head(10)

top_locality_cost_counts
# Out:
#                  Locality  Average Cost for two  Count
# 448         Chandni Chowk                   100     20
# 2616                Palam                   200     16
# 3739             Shahdara                   300     16
# 2233  Mayur Vihar Phase 1                   300     16
# 2357      Mukherjee Nagar                   200     15
# 2917       Rajinder Nagar                   300     15
# 2355      Mukherjee Nagar                   100     15
# 2759            Pitampura                   400     14
# 4187          Tilak Nagar                   300     14
# 3036           Safdarjung                   500     14

# %%
plt.figure(figsize=(7, 6))
plt.barh(top_locality_cost_counts['Locality'],top_locality_cost_counts['Average Cost for two'], color='m')
plt.ylabel('Name of Localities')
plt.xlabel('Average Cost for two')
plt.title('Top 10 localities vs Average Cost for two')
plt.gca().invert_yaxis()
plt.show()

# %%
locality_price_counts = df.groupby(['Locality', 'Price range']).size().reset_index(name='Count')
top_locality_price_counts = locality_price_counts.sort_values(by='Count', ascending=False).head(10)

top_locality_price_counts
# Out:
#                  Locality  Price range  Count
# 1631             Shahdara            1     75
# 333       Connaught Place            3     66
# 1132      Mukherjee Nagar            1     63
# 1078  Mayur Vihar Phase 1            1     62
# 274         Chandni Chowk            1     61
# 1146            Najafgarh            1     56
# 913         Krishna Nagar            1     56
# 1911   Vasundhara Enclave            1     56
# 1882          Uttam Nagar            1     54
# 1836          Tilak Nagar            1     53

# %%
plt.figure(figsize=(7, 6))
plt.barh(top_locality_price_counts['Locality'],top_locality_price_counts['Price range'], color='c')
plt.ylabel('Name of Localities')
plt.xlabel('Price range')
plt.title('Top 10 localities vs Price range')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    Restaurant Name  City  Locality  Longitude  Latitude  Cuisines  \
# 0             3749    73       171       8042       384       920
# 1             3173    73       593       8041       382      1111
# 2             2897    75       308       8053       388      1671
# 3             4707    75       862       8050       391      1126
# 4             5523    75       862       8055       390      1122
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                    73         0                  1                    0
# 1                    75         0                  1                    0
# 2                   113         0                  1                    0
# 3                    81         0                  0                    0
# 4                    81         0                  1                    0
#
#    Is delivering now  Price range  Aggregate rating  Rating text  Votes  \
# ...

# %%
#checking for skewness
plt.figure(figsize=(20,30),facecolor='lightgrey')
pltnum=1

for i in df.columns:
    if pltnum<=16:
        ax=plt.subplot(6,3,pltnum)
        sns.distplot(df[i],color='m',hist=False,kde_kws={'shade':True})
        plt.xlabel(i,fontsize=15,fontweight='bold')
        pltnum+=1
plt.tight_layout()
plt.show()
print(df.skew())
# Out:
# Restaurant Name          0.044637
# City                    -1.193777
# Locality                -0.253554
# Longitude                0.050762
# Latitude                 0.043785
# Cuisines                -0.305484
# Average Cost for two     0.089636
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Price range              0.889618
# Aggregate rating        -0.296072
# Rating text              0.431408
# Votes                    2.445367
# Country                  3.312721
# dtype: float64

# %% [markdown]
# 'Is delivering now' have high positive skewness.

# %%
#droping column 'delivering now'
df=df.drop(columns=['Is delivering now'])

# %%
#checking for outliers
plt.figure(figsize=(20,30),facecolor='lightgrey')
pltnum=1

for i in df.columns:
    if pltnum<=16:
        ax=plt.subplot(6,3,pltnum)
        sns.boxplot(df[i],color='c')
        plt.xlabel(i,fontsize=15,fontweight='bold')
        pltnum+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# Outliers are presnt in 'City','Currency','Votes','Country' columns.

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold=3
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (8372, 15)

# %%
lose=(df.shape[0]-df1.shape[0])/df.shape[0]*100
print('Percentage of datalose is :',lose)
# Out:
# Percentage of datalose is : 12.344257145848603

# %% [markdown]
# # Correlaion

# %%
df1.corr()
# Out:
#                       Restaurant Name      City  Locality  Longitude  \
# Restaurant Name              1.000000  0.008304  0.008172   0.013928
# City                         0.008304  1.000000 -0.030005   0.257471
# Locality                     0.008172 -0.030005  1.000000  -0.019048
# Longitude                    0.013928  0.257471 -0.019048   1.000000
# Latitude                     0.000159  0.419855 -0.037177   0.172757
# Cuisines                     0.060679  0.029500 -0.011591   0.016522
# Average Cost for two         0.052481 -0.087771 -0.086885  -0.060665
# Currency                     0.000577 -0.053468  0.037207   0.003590
# Has Table booking            0.037724 -0.017452 -0.076927  -0.015402
# Has Online delivery          0.033268 -0.026266 -0.046911   0.029554
# Price range                  0.057875 -0.072659 -0.093854  -0.003000
# Aggregate rating             0.021039 -0.084453 -0.159184   0.021799
# Rating text                 -0.000382 -0.034483  0.006531  -0.039310
# ...

# %%
plt.figure(figsize=(22,18))
sns.heatmap(df1.corr(),annot=True,fmt='.2f',linecolor='Black',linewidth=0.2,cmap='Blues')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,10))
data=df1.corr()['Price range'].sort_values(ascending=False)
indices=data.index
labels=[]
corr=[]
for i in range (1,len(indices)):
    labels.append(indices[i])
    corr.append(data[i])
sns.barplot(x=labels,y=corr,palette='Dark2')
plt.xticks(fontweight='bold',rotation=90)
plt.title('Correlation coefficient between Price range and other features',fontweight='bold',fontsize=15)
plt.show()

# %% [markdown]
# Price range is :
#
# * positively correlated with "Average cost for two","Has Table Booking","Votes","Aggregate rating"
# * negatively correlated with "Latitude","Locality"

# %%
plt.figure(figsize=(12,10))
data=df1.corr()['Average Cost for two'].sort_values(ascending=False)
indices=data.index
labels=[]
corr=[]
for i in range (1,len(indices)):
    labels.append(indices[i])
    corr.append(data[i])
sns.barplot(x=labels,y=corr,palette='Dark2')
plt.xticks(fontweight='bold',rotation=90)
plt.title('Correlation coefficient between Average Cost for two and other features',fontweight='bold',fontsize=15)
plt.show()

# %% [markdown]
# Average cost for two:
# *  positively correlated with "Price rating","Has Table booking","Votes","Agrgregate rating"
# * Negatively correlated with "Latitude","City".

# %% [markdown]
# # Model Building

# %%
#splitting data
x=df1.drop(columns=['Price range'])
y=df1['Price range']

# %%
X=df1.drop(columns=['Average Cost for two'])
Y=df1['Average Cost for two']

# %% [markdown]
# # 1) Model building to predict "Price range"

# %%
print(x.shape,y.shape)
# Out:
# (8372, 14) (8372,)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
x_scale=st.fit_transform(x)
x_new=pd.DataFrame(x_scale,columns=x.columns)

# %%
x=x_new

# %% [markdown]
# # Varience Inflation Factor
# Varience_inflation_factor is used to check for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Features list']=x.columns
vif['Vif value']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#            Features list  Vif value
# 0        Restaurant Name   1.007837
# 1                   City   1.299510
# 2               Locality   1.039824
# 3              Longitude   1.090665
# 4               Latitude   1.291392
# 5               Cuisines   1.029446
# 6   Average Cost for two   1.717594
# 7               Currency   1.053245
# 8      Has Table booking   1.488888
# 9    Has Online delivery   1.126087
# 10      Aggregate rating   1.758835
# 11           Rating text   1.230444
# 12                 Votes   1.808457
# 13               Country   1.078770

# %% [markdown]
# # Model Building

# %%
#importing libraries
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,RandomForestClassifier,ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=45)

# %%
model=[LogisticRegression(),SVC(),KNeighborsClassifier(),GradientBoostingClassifier(),AdaBoostClassifier(),RandomForestClassifier(),ExtraTreesClassifier(),GaussianNB(),DecisionTreeClassifier()]

# %% [markdown]
# # Finding best RandomState

# %%
maxAccu=0
maxRS=0

for i in range (0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print('Maximum Accuracy score is :',maxAccu,'On Random State :',maxRS)
# Out:
# Maximum Accuracy score is : 0.9474626865671641 On Random State : 97

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=97)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (6697, 14) (6697,)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (1675, 14) (1675,)

# %% [markdown]
# # Evaluation Metrics of different models

# %%
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('Evaluation Metrics of ',m,':\n')
    print('Accuracy score :\n',accuracy_score(y_test,pred))
    print('\n')
    print('Confusion matrix :\n',confusion_matrix(y_test,pred))
    print('\n')
    print('Classification Report :\n',classification_report(y_test,pred))
    print('_'*125)
# Out:
# Evaluation Metrics of  LogisticRegression() :
#
# Accuracy score :
#  0.9474626865671641
#
#
# Confusion matrix :
#  [[783  31   0   0]
#  [  9 562   4   0]
#  [  0  24 181   2]
#  [  0   1  17  61]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       814
#            1       0.91      0.98      0.94       575
#            2       0.90      0.87      0.89       207
#            3       0.97      0.77      0.86        79
#
#     accuracy                           0.95      1675
#    macro avg       0.94      0.90      0.92      1675
# weighted avg       0.95      0.95      0.95      1675
#
# _____________________________________________________________________________________________________________________________
# Evaluation Metrics of  SVC() :
#
# Accuracy score :
#  0.933134328358209
#
#
# Confusion matrix :
#  [[780  34   0   0]
#  [ 12 556   7   0]
#  [  0  28 172   7]
# ...

# %% [markdown]
# RandomForestClassifier is giving good accuracy score 0.983

# %% [markdown]
# # Cross Validation Score

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Cross Validation Score of ',m,'is :\n')
    print('Score :',score)
    print('Mean Score :',score.mean())
    print('Standard Deviation :',score.std())
    print('_'*125)
# Out:
# Cross Validation Score of  LogisticRegression() is :
#
# Score : [0.90149254 0.90746269 0.94205496 0.92712067 0.90860215]
# Mean Score : 0.9173466003316749
# Standard Deviation : 0.015043562310038625
# _____________________________________________________________________________________________________________________________
# Cross Validation Score of  SVC() is :
#
# Score : [0.79880597 0.88537313 0.94623656 0.9432497  0.89605735]
# Mean Score : 0.8939445425203731
# Standard Deviation : 0.05346912122453721
# _____________________________________________________________________________________________________________________________
# Cross Validation Score of  KNeighborsClassifier() is :
#
# Score : [0.56       0.64537313 0.75388292 0.79091995 0.72759857]
# Mean Score : 0.6955549136040229
# Standard Deviation : 0.08296600220273917
# _____________________________________________________________________________________________________________________________
# ...

# %% [markdown]
# # Hyper Parameter Tuning

# %%
param={'n_estimators':[30,50,60],'max_depth': [10,20,40,60,80],
             'criterion':['gini','entropy'],'max_features':["auto","sqrt","log2"]}

# %%
grid=GridSearchCV(estimator=RandomForestClassifier(),param_grid=param,cv=5)
grid.fit(x,y)
print(grid)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 40, 60, 80],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [30, 50, 60]})

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 60}
# 0.9654847625670928

# %%
final_model=RandomForestClassifier(criterion='entropy', max_depth= 40, max_features='sqrt',n_estimators=60)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
print('Evaluation Metrics of ',final_model,':\n')
print('Accuracy score :\n',accuracy_score(y_test,pred))
print('\n')
print('Confusion matrix :\n',confusion_matrix(y_test,pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,pred))
# Out:
# Evaluation Metrics of  RandomForestClassifier(criterion='entropy', max_depth=40, n_estimators=60) :
#
# Accuracy score :
#  0.9832835820895522
#
#
# Confusion matrix :
#  [[813   1   0   0]
#  [  2 573   0   0]
#  [  0   6 198   3]
#  [  0   2  14  63]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       814
#            1       0.98      1.00      0.99       575
#            2       0.93      0.96      0.95       207
#            3       0.95      0.80      0.87        79
#
#     accuracy                           0.98      1675
#    macro avg       0.97      0.94      0.95      1675
# weighted avg       0.98      0.98      0.98      1675

# %%
sns.heatmap(confusion_matrix(y_test,pred),annot=True,cmap='Dark2',fmt='d',linecolor='black',linewidth=.1)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap',fontweight='bold',fontsize=10)
# Out:
# Text(0.5, 1.0, 'Confusion Matrix Heatmap')

# %% [markdown]
# # Saving model

# %%
import joblib

# %%
joblib.dump(final_model,'Zomato Restaurant.obj')
# Out:
# ['Zomato Restaurant.obj']

# %% [markdown]
# # Final Prediction

# %%
prediction=final_model.predict(x_test)
actual=np.array(y_test)
def_pred=pd.DataFrame()
def_pred['Predicted Price range']=prediction
def_pred['Actual Price range']=actual
def_pred
# Out:
#       Predicted Price range  Actual Price range
# 0                         1                   1
# 1                         3                   3
# 2                         1                   1
# 3                         0                   0
# 4                         2                   2
# ...                     ...                 ...
# 1670                      0                   0
# 1671                      0                   0
# 1672                      1                   1
# 1673                      1                   1
# 1674                      0                   0
#
# [1675 rows x 2 columns]

# %%
def_pred['Predicted Price range']=def_pred['Predicted Price range'].replace({0:'1',1:'2',2:'3',3:'4'})
def_pred['Actual Price range']=def_pred['Actual Price range'].replace({0:'1',1:'2',2:'3',3:'4'})
def_pred
# Out:
#      Predicted Price range Actual Price range
# 0                        2                  2
# 1                        4                  4
# 2                        2                  2
# 3                        1                  1
# 4                        3                  3
# ...                    ...                ...
# 1670                     1                  1
# 1671                     1                  1
# 1672                     2                  2
# 1673                     2                  2
# 1674                     1                  1
#
# [1675 rows x 2 columns]

# %% [markdown]
# #  2) Model building to predict "Average Cost for two"

# %%
print(X.shape,Y.shape)
# Out:
# (8372, 14) (8372,)

# %% [markdown]
# # Scaling

# %%
st=StandardScaler()

# %%
Xscale=st.fit_transform(X)
X=pd.DataFrame(Xscale,columns=X.columns)

# %% [markdown]
# # Varience Inflation Factor

# %%
VIF=[]
VIF=pd.DataFrame()
VIF['Features List']=X.columns
VIF['VIF value']=[variance_inflation_factor(X.values,i) for i in range (len(X.columns))]
VIF
# Out:
#           Features List  VIF value
# 0       Restaurant Name   1.008597
# 1                  City   1.299953
# 2              Locality   1.039817
# 3             Longitude   1.087221
# 4              Latitude   1.319510
# 5              Cuisines   1.031021
# 6              Currency   1.054795
# 7     Has Table booking   1.522908
# 8   Has Online delivery   1.107027
# 9           Price range   1.904997
# 10     Aggregate rating   1.817143
# 11          Rating text   1.237641
# 12                Votes   1.818818
# 13              Country   1.095946

# %%
#importing libraries
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.2,random_state=45)

# %%
model=[LinearRegression(),Lasso(),Ridge(),SVR(),RandomForestRegressor(),GradientBoostingRegressor(),AdaBoostRegressor(),ExtraTreesRegressor(),DecisionTreeRegressor(),KNeighborsRegressor()]

# %% [markdown]
# # Finding Best Random State

# %%
maxScore=0
maxRS=0

for i in range (0,200):
    x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.02,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    lr.score(x_train,y_train)
    score=r2_score(y_test,pred)
    if score>maxScore:
        maxScore=score
        maxRs=i
        
print('Maximum Acuracy score is :',maxScore,'On Random State :',maxRS)
# Out:
# Maximum Acuracy score is : 0.8219801614749169 On Random State : 0

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.2,random_state=0)

# %%
print(x_train.shape,x_train.shape)
# Out:
# (6697, 14) (6697, 14)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (1675, 14) (1675,)

# %% [markdown]
# # Evaluation Matrics of Different models.

# %%
for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('Evaluation metrics of',m,':')
    print(f" R2 score is: {r2_score(y_test,pred)*100}")
    print ('\n','mean_absolute_error:','\n',mean_absolute_error(y_test,pred))
    print ('\n','mean_squared_error:','\n',mean_squared_error(y_test,pred))
    print('_'*125)
# Out:
# Evaluation metrics of LinearRegression() :
#  R2 score is: 71.44571137152084
#
#  mean_absolute_error:
#  6.980618026432135
#
#  mean_squared_error:
#  94.70640706033072
# _____________________________________________________________________________________________________________________________
# Evaluation metrics of Lasso() :
#  R2 score is: 68.50809927907868
#
#  mean_absolute_error:
#  7.202546074187971
#
#  mean_squared_error:
#  104.44962602936148
# _____________________________________________________________________________________________________________________________
# Evaluation metrics of Ridge() :
#  R2 score is: 71.44544900197816
#
#  mean_absolute_error:
#  6.980640591822505
#
#  mean_squared_error:
#  94.70727726504957
# _____________________________________________________________________________________________________________________________
# Evaluation metrics of SVR() :
#  R2 score is: 72.78649933587313
#
#  mean_absolute_error:
#  6.593001081462228
#
# ...

# %% [markdown]
# We will go with RandomForestRegressor with r2 score of 85.66

# %% [markdown]
# # Cross Validation Score

# %%
for m in model:
    score=cross_val_score(m,X,Y,cv=5)
    print('Cross Validation Score of ',m,'is :\n')
    print('Score :',score)
    print('Mean Score :',score.mean())
    print('Standard Deviation :',score.std())
    print('_'*125)
# Out:
# Cross Validation Score of  LinearRegression() is :
#
# Score : [-0.1571815   0.78720267  0.72966417  0.77756012 -0.52405975]
# Mean Score : 0.32263713909953246
# Standard Deviation : 0.5541784207911137
# _____________________________________________________________________________________________________________________________
# Cross Validation Score of  Lasso() is :
#
# Score : [-0.05003528  0.7779593   0.71581565  0.76482272 -0.24143229]
# Mean Score : 0.39342602361300566
# Standard Deviation : 0.4448459112837142
# _____________________________________________________________________________________________________________________________
# Cross Validation Score of  Ridge() is :
#
# Score : [-0.15661505  0.78719216  0.72965333  0.7775393  -0.523518  ]
# Mean Score : 0.3228503481464645
# Standard Deviation : 0.5539080196537605
# _____________________________________________________________________________________________________________________________
# ...

# %% [markdown]
# # Hyper Parameter Tuning

# %%
param={ 'n_estimators':[30,50,60],'max_depth': [10,20,40,60,80],
             'max_features':["auto","sqrt","log2"]
    }

# %%
grid=GridSearchCV(estimator=RandomForestRegressor(),param_grid=param,cv=5)
grid.fit(X,Y)

# %%
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# model has been built after hypertunning it the code is not mentioned as it took large time to execute

# %%
final_model=RandomForestRegressor(n_estimators = 60,max_depth =40,max_features='sqrt')
final_model.fit(x_train,y_train)
final_model.predict(x_test)
print('Evaluation metrics of',final_model,':')
print(f" R2 score is: {r2_score(y_test,pred)*100}")
print ('\n','mean_absolute_error:','\n',mean_absolute_error(y_test,pred))
print ('\n','mean_squared_error:','\n',mean_squared_error(y_test,pred))
# Out:
# Evaluation metrics of RandomForestRegressor(max_depth=40, max_features='sqrt', n_estimators=60) :
#  R2 score is: 75.50702155092989
#
#  mean_absolute_error:
#  6.875701492537313
#
#  mean_squared_error:
#  81.23620298507461

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,pred,color ='r')
plt.plot(y_test,y_test,color ='b')
plt.xlabel('Actual Average cost for two ',fontsize = 14)
plt.ylabel('Predicted Average Cost for two',fontsize =14)
plt.title('RFR',fontsize = 18)
plt.show()

# %% [markdown]
# # Saving model

# %%
joblib.dump(final_model,'Zomato Restaurant.average cost for two.obj')
# Out:
# ['Zomato Restaurant.average cost for two.obj']

# %% [markdown]
# # Final Prediction

# %%
prediction=final_model.predict(x_test)
actual=np.array(y_test)
def_pred=pd.DataFrame()
def_pred['Predicted Average Cost for two']=prediction
def_pred['Actual Average Cost for two']=actual
def_pred
# Out:
#       Predicted Average Cost for two  Actual Average Cost for two
# 0                          37.000000                           50
# 1                          42.400000                           50
# 2                          78.666667                           75
# 3                          40.500000                           32
# 4                          80.283333                           84
# ...                              ...                          ...
# 1670                       43.900000                           47
# 1671                       36.700000                           50
# 1672                       72.066667                           71
# 1673                       30.950000                           32
# 1674                       94.450000                           92
#
# [1675 rows x 2 columns]

# %% [markdown]
# # ______________  Thank You  ________________
