# %% [markdown]
# # Census Income

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#importing data
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/refs/heads/master/census_income.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#checking shape
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# Dataset contains 32560 rows and 15 columns.

# %%
#checking for columns
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
#checking for the datatype of each column
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
#checking for info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# In the data set 6 columns are of type int64 and 9 columns are of type object.Also there is no null values in the dataset.

# %%
#chcking for duplicate values
df.duplicated().sum()
# Out:
# 24

# %% [markdown]
# There are 24 duplicate values are there inthe dataset.

# %%
#droping duplicate values
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (32536, 15)

# %% [markdown]
# Here we can see the reduce in the number of rows .

# %%
#Checking for value counts
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
#checking for unique for each columns
for i in df.columns:
    print(df[i].value_counts())
    print('_'*50)
# Out:
# 36    898
# 31    888
# 34    886
# 23    876
# 33    875
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
# __________________________________________________
#  Private             22673
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# __________________________________________________
# 123011    13
# 164190    13
# 203488    13
# 121124    12
# 126675    12
#           ..
# 158040     1
# 232784     1
# 325573     1
# 140176     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
# __________________________________________________
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
# ...

# %% [markdown]
# we can observe '?' in the dataset .

# %%
#checking for ? values
df.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     582
# Income               0
# dtype: int64

# %%
#replacing  ? value.
for i in df.columns:
    df[i].replace([' ?'],df[i].mode()[0],inplace=True)

# %%
df.isin([' ?']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#checkin for zero values
df.isin([0]).sum()
# Out:
# Age                   0
# Workclass             0
# Fnlwgt                0
# Education             0
# Education_num         0
# Marital_status        0
# Occupation            0
# Relationship          0
# Race                  0
# Sex                   0
# Capital_gain      29825
# Capital_loss      31017
# Hours_per_week        0
# Native_country        0
# Income                0
# dtype: int64

# %%
(df.isin([0]).sum()/len(df))*100
# Out:
# Age                0.000000
# Workclass          0.000000
# Fnlwgt             0.000000
# Education          0.000000
# Education_num      0.000000
# Marital_status     0.000000
# Occupation         0.000000
# Relationship       0.000000
# Race               0.000000
# Sex                0.000000
# Capital_gain      91.667691
# Capital_loss      95.331325
# Hours_per_week     0.000000
# Native_country     0.000000
# Income             0.000000
# dtype: float64

# %% [markdown]
# The values of column capital_gain and capital_loss have 91% and 95% data are zeros so we will drop these two columns.

# %%
df.drop(columns=['Capital_gain','Capital_loss'],inplace=True,axis=1)

# %%
#separating numerical and categorical columns
cat_col=[]
for i in df.columns:
    if df.dtypes[i]=='object':
        cat_col.append(i)
print('Categorical columns :',cat_col)
print('\n')

num_col=[]
for i in df.columns:
    if df.dtypes[i] != 'object':
        num_col.append(i)
print('Numerical Columns :',num_col)
# Out:
# Categorical columns : ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']
#
#
# Numerical Columns : ['Age', 'Fnlwgt', 'Education_num', 'Hours_per_week']

# %%
#checking for null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#visualization
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# There are no presense of null values in the dataset.

# %% [markdown]
# # Stastical Analysis

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Hours_per_week
# count  32536.000000  3.253600e+04   32536.000000    32536.000000
# mean      38.585536  1.897843e+05      10.081725       40.440343
# std       13.638193  1.055563e+05       2.571622       12.347079
# min       17.000000  1.228500e+04       1.000000        1.000000
# 25%       28.000000  1.178315e+05       9.000000       40.000000
# 50%       37.000000  1.783560e+05      10.000000       40.000000
# 75%       48.000000  2.369932e+05      12.000000       45.000000
# max       90.000000  1.484705e+06      16.000000       99.000000

# %% [markdown]
# 1) All counts are same indicates there are no null values
# 2) Mean is greater then median indicates the dataset is right skewed.
# 3) The gap between 75 and max indicates the presence of outliers.
# 4) Maximum age is 90 and minimum age is 17.
# 5) Maximium working hour is 99,minimum working hour is 1 and average working hour is 40.

# %% [markdown]
# # Exploratory Data Analysis(EDA) and Visualization

# %%
print(df['Income'].value_counts())
sns.countplot(x='Income', data=df, palette='bright')
# Out:
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64
# <Axes: xlabel='Income', ylabel='count'>

# %% [markdown]
# More people earn 50k or less compared to those who earn more than 50k.

# %%
sns.set_palette('muted')
plt.figure(figsize=(20,20),facecolor='white')
for i,col in enumerate(cat_col,1):
    plt.subplot(5,2,i)
    sns.countplot(data=df,x=col,)
    plt.xlabel(col,fontsize=30)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,40),facecolor='lightgrey')

for i, col in enumerate(cat_col, 1):
    plt.subplot(5, 2, i)
    sns.countplot(data=df, x=col,hue='Income',palette='colorblind')
    plt.xlabel(col, fontsize=20)
    plt.xticks(fontsize=15,fontweight ='bold',rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# People working in the private sector, who have a high school education, have never been married, work in professional specialties, are not part of a family unit, and are male, typically have an income of 50k or less.

# %%
plt.figure(figsize=(6,4))
for col in num_col:
    plt.title(col+'VS Income')
    sns.barplot(y=col,x='Income',data=df,palette='inferno')
    plt.show()

# %% [markdown]
# * Peoples of age greater then 40 earning more then greater then 50k
# * peoples who are working less then 40 hours per week earning less then or equal to 50k.

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in cat_col:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Hours_per_week  Native_country  \
# ...

# %%
#checking for skewness
plt.figure(figsize=(20,25),facecolor='gold')
pltnum=1
for col in df:
    if pltnum<=13:
        ax=plt.subplot(5,3,pltnum)
        sns.distplot(df[col],color='brown',hist=False,kde_kws={'shade':True})
        plt.xlabel(col,fontsize=15)
    pltnum+=1
plt.show()
print(df.skew())
# Out:
# Age               0.557657
# Workclass         0.075983
# Fnlwgt            1.447695
# Education        -0.934180
# Education_num    -0.309454
# Marital_status   -0.012692
# Occupation        0.000407
# Relationship      0.786514
# Race             -2.435283
# Sex              -0.719400
# Hours_per_week    0.228752
# Native_country   -4.247065
# Income            1.211640
# dtype: float64

# %% [markdown]
# The distributions of the columns "Race" and "Native_country" are skewed to the left. However, all other columns are approximately normally distributed.

# %%
#checking for outliers
plt.figure(figsize=(20,25),facecolor='gold')
pltnum=1
for col in df:
    if pltnum<=13:
        ax=plt.subplot(5,3,pltnum)
        sns.boxplot(df[col],color='brown')
        plt.xlabel(col,fontsize=15)
    pltnum+=1
plt.show()

# %% [markdown]
# There is presence of outliers in the dataset.

# %% [markdown]
# # Removal of outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold=3
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (29277, 13)

# %%
#percentage of data lose
lose=(df.shape[0]-df1.shape[0])/df.shape[0]*100
print('percentage of data lose is :',lose)
# Out:
# percentage of data lose is : 10.016597000245882

# %% [markdown]
# # Correlation

# %%
df1.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.035649 -0.075938   0.000381       0.056521
# Workclass       0.035649   1.000000 -0.025061   0.003914       0.003308
# Fnlwgt         -0.075938  -0.025061  1.000000  -0.022599      -0.037017
# Education       0.000381   0.003914 -0.022599   1.000000       0.341300
# Education_num   0.056521   0.003308 -0.037017   0.341300       1.000000
# Marital_status -0.286309  -0.020856  0.028885  -0.039393      -0.065135
# Occupation      0.000467   0.007576  0.003251  -0.040923       0.076649
# Relationship   -0.271453  -0.056948  0.013702  -0.011770      -0.098403
# Race            0.023820   0.066730 -0.101142   0.028024       0.086799
# Sex             0.094606   0.071142  0.023629  -0.028543       0.010937
# Hours_per_week  0.096319   0.030858 -0.017969   0.060236       0.166038
# Native_country  0.037309   0.002560 -0.103580   0.090287       0.146072
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='.2f',cmap='Paired')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
data=df1.corr()['Income'].sort_values(ascending=False)
indices=data.index
labels=[]
corr=[]
for i in range(1,len(indices)):
    labels.append(indices[i])
    corr.append(data[i])
sns.barplot(x=labels,y=corr,palette='muted')
plt.xticks(rotation=90)
plt.title('correlation coefficient between different features and Income')

plt.show()

# %% [markdown]
# Target column Income is
# 1) Positively correlated with Education_num,Age,Hours_per_week,sex.
# 2) Negatively correlated with Relationship,marital_status.

# %%
#splitting the dataset
x=df1.drop('Income',axis=1)
y=df1['Income']

# %%
x.shape,y.shape
# Out:
# ((29277, 12), (29277,))

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()
X=st.fit_transform(x)

# %%
X=pd.DataFrame(X,columns=x.columns)

# %% [markdown]
# # Multicollinearity

# %% [markdown]
#  We use Varience_inflation_factor check for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['features List']=X.columns
vif['VIF values']=[variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif
# Out:
#      features List  VIF values
# 0              Age    1.169906
# 1        Workclass    1.009934
# 2           Fnlwgt    1.028648
# 3        Education    1.142240
# 4    Education_num    1.204702
# 5   Marital_status    1.140980
# 6       Occupation    1.017281
# 7     Relationship    1.691905
# 8             Race    1.048750
# 9              Sex    1.567105
# 10  Hours_per_week    1.145524
# 11  Native_country    1.035426

# %% [markdown]
# # Model Building

# %%
#importing libraries
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,AdaBoostClassifier,ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=45)

# %%
model=[LogisticRegression(),SVC(),KNeighborsClassifier(),GradientBoostingClassifier(),RandomForestClassifier(),AdaBoostClassifier(),ExtraTreesClassifier(),GaussianNB(),DecisionTreeClassifier()]

# %% [markdown]
# # Finding best Random State

# %%
maxAccu=0
maxRS=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=i)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum Accuracy Score Is :',maxAccu,'On RandomState :',maxRS)
# Out:
# Maximum Accuracy Score Is : 0.8183060109289617 On RandomState : 99

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=99)

# %%
x_train.shape,y_train.shape
# Out:
# ((23421, 12), (23421,))

# %%
x_test.shape,y_test.shape
# Out:
# ((5856, 12), (5856,))

# %% [markdown]
# # Evaluation metrics

# %%
for m in model:
    m.fit(x_train,y_train)
    y_pred=m.predict(x_test)
    print('Evaluation Metrics of ',m,':')
    print('\n')
    print('Accuracy Score :\n',accuracy_score(y_test,y_pred))
    print('\n')
    print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred))
    print('\n')
    print('Classification Report :\n',classification_report(y_test,y_pred))
    print('_'*100)
# Out:
# Evaluation Metrics of  LogisticRegression() :
#
#
# Accuracy Score :
#  0.8183060109289617
#
#
# Confusion Matrix :
#  [[4213  283]
#  [ 781  579]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      4496
#            1       0.67      0.43      0.52      1360
#
#     accuracy                           0.82      5856
#    macro avg       0.76      0.68      0.70      5856
# weighted avg       0.80      0.82      0.80      5856
#
# ____________________________________________________________________________________________________
# Evaluation Metrics of  SVC() :
#
#
# Accuracy Score :
#  0.8364071038251366
#
#
# Confusion Matrix :
#  [[4237  259]
#  [ 699  661]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      4496
#            1       0.72      0.49      0.58      1360
#
# ...

# %% [markdown]
# Here AdaBoostClassifier is giving best accuracy score that is 0.8423

# %% [markdown]
# # Cross Validation Score

# %%
ad=AdaBoostClassifier()
score=cross_val_score(ad,X,y,cv=5)
print('\n')
print('Cross Validation Score Of ',ad,':')
print('\n')
print('Score :',score)
print('Mean Score :',score.mean())
print('Standard Deviation :',score.std())
# Out:
# Cross Validation Score Of  AdaBoostClassifier() :
#
#
# Score : [0.83367486 0.8329918  0.8353544  0.84355252 0.83842869]
# Mean Score : 0.8368004554511813
# Standard Deviation : 0.0038628425640017125

# %% [markdown]
# # Hyper Parameter Tuning

# %%
param={'n_estimators':[100,500,1000],
              'algorithm':['SAMME', 'SAMME.R'],
              'learning_rate':[.001,0.01,.1],
              'base_estimator': [DecisionTreeClassifier(max_depth=1), DecisionTreeClassifier(max_depth=2)] }

# %%
grid=GridSearchCV(estimator=AdaBoostClassifier(),param_grid=param,cv=3)
grid.fit(X,y)
print(grid)
# Out:
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'base_estimator': [DecisionTreeClassifier(max_depth=1),
#                                             DecisionTreeClassifier(max_depth=2)],
#                          'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [100, 500, 1000]})

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'algorithm': 'SAMME.R', 'base_estimator': DecisionTreeClassifier(max_depth=2), 'learning_rate': 0.1, 'n_estimators': 500}
# 0.8391228609488678

# %%
final_model=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=DecisionTreeClassifier(max_depth=2), learning_rate= 0.1, n_estimators=500)
final_model.fit(x_train,y_train)
y_pred=final_model.predict(x_test)
print('Accuracy Score :\n',accuracy_score(y_test,y_pred))
print('\n')
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred))
print('\n')
print('Classification Report :\n',classification_report(y_test,y_pred))
# Out:
# Accuracy Score :
#  0.8457991803278688
#
#
# Confusion Matrix :
#  [[4148  348]
#  [ 555  805]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      4496
#            1       0.70      0.59      0.64      1360
#
#     accuracy                           0.85      5856
#    macro avg       0.79      0.76      0.77      5856
# weighted avg       0.84      0.85      0.84      5856

# %% [markdown]
# # AUC-ROC Curve

# %%
final_model.fit(x_train,y_train)
y_pred_prob=final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
auc_score=roc_auc_score(y_test,final_model.predict(x_test))
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='AUC ='+str(round(auc_score,2)))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.title(final_model)
plt.show()

# %%
import joblib

# %%
joblib.dump(final_model,'Census Income.obj')
# Out:
# ['Census Income.obj']

# %% [markdown]
# # Final Prediction

# %%
predictions=final_model.predict(x_test)
actual=np.array(y_test)
df_pred=pd.DataFrame()
df_pred['Predicted Income']=predictions
df_pred['Actual Income']=actual
df_pred
# Out:
#       Predicted Income  Actual Income
# 0                    0              0
# 1                    0              0
# 2                    0              1
# 3                    0              0
# 4                    0              0
# ...                ...            ...
# 5851                 0              0
# 5852                 0              0
# 5853                 0              0
# 5854                 0              0
# 5855                 1              1
#
# [5856 rows x 2 columns]

# %%
df_pred['Predicted Income'] = df_pred['Predicted Income'].replace({0: '<=50k', 1: '>50k'})
df_pred['Actual Income'] = df_pred['Actual Income'].replace({0: '<=50k', 1: '>50k'})
df_pred
# Out:
#      Predicted Income Actual Income
# 0               <=50k         <=50k
# 1               <=50k         <=50k
# 2               <=50k          >50k
# 3               <=50k         <=50k
# 4               <=50k         <=50k
# ...               ...           ...
# 5851            <=50k         <=50k
# 5852            <=50k         <=50k
# 5853            <=50k         <=50k
# 5854            <=50k         <=50k
# 5855             >50k          >50k
#
# [5856 rows x 2 columns]

# %% [markdown]
# # ______________________ Thank You  __________________________
